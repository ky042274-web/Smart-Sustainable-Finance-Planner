# %%
# ==========================================================
# CELL 1 → INSTALL REQUIRED LIBRARIES
# ==========================================================

# !pip install streamlit plotly pandas
# Out:
# Requirement already satisfied: streamlit in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (1.56.0)
# Requirement already satisfied: plotly in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (6.7.0)
# Requirement already satisfied: pandas in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (3.0.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (7.0.6)
# Requirement already satisfied: click<9,>=7.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (8.3.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (3.1.47)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging>=20 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (26.1)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (7.34.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (2.33.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (6.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from plotly) (2.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: jinja2 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: colorama in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: six>=1.5 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\riwi9\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ==========================================================
# CELL 2 → IMPORT LIBRARIES
# ==========================================================

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from IPython.display import display, HTML
import ipywidgets as widgets

# %%
# ==========================================================
# CELL 3 → TITLE & INTRODUCTION
# ==========================================================

title_html = """
<div style="
    background: linear-gradient(90deg,#1B5E20,#1565C0);
    padding:20px;
    border-radius:15px;
    color:white;
    text-align:center;
    margin-bottom:20px;
">
    <h1>🌱 Smart Sustainable Finance Planner</h1>
    <h3>Middle Class Sustainable Finance Dashboard</h3>
    <p>
    ✅ Budget Planning &nbsp;&nbsp;
    ✅ Savings & SIP &nbsp;&nbsp;
    ✅ Emergency Fund &nbsp;&nbsp;
    ✅ Government Schemes
    </p>
</div>
"""

display(HTML(title_html))
# Out:
# <div style="
#     background: linear-gradient(90deg,#1B5E20,#1565C0);
#     padding:20px;
#     border-radius:15px;
#     color:white;
#     text-align:center;
#     margin-bottom:20px;
# ">
#     <h1>🌱 Smart Sustainable Finance Planner</h1>
#     <h3>Middle Class Sustainable Finance Dashboard</h3>
#     <p>
#     ✅ Budget Planning &nbsp;&nbsp;
#     ✅ Savings & SIP &nbsp;&nbsp;
#     ✅ Emergency Fund &nbsp;&nbsp;
#     ✅ Government Schemes
#     </p>
# </div>

# %%
# ==========================================================
# CELL 4 → USER INPUTS
# ==========================================================

name = input("Enter Your Name: ")

monthly_salary = float(input("Monthly Salary (₹): "))
age = int(input("Your Age: "))
family_members = int(input("Family Members: "))

print("\n========== Monthly Expenses ==========\n")

rent = float(input("House Rent / EMI: "))
groceries = float(input("Groceries: "))
transport = float(input("Transport: "))
school_fees = float(input("School Fees: "))
electricity = float(input("Electricity + Internet: "))
entertainment = float(input("Entertainment: "))
loan_emi = float(input("Loan EMI: "))
other_expenses = float(input("Other Expenses: "))

print("\n========== Savings & Insurance ==========\n")

emergency_fund = float(input("Emergency Fund Saved: "))
investments = float(input("Current Investments: "))

health_insurance = input(
    "Health Insurance (No Insurance / Employer Insurance Only / Basic Insurance / Good Insurance): "
)
# Out:
# Enter Your Name:  Rewati
# Monthly Salary (₹):  60000
# Your Age:  29
# Family Members:  5
# ========== Monthly Expenses ==========
# House Rent / EMI:  9000
# Groceries:  5000
# Transport:  4000
# School Fees:  0
# Electricity + Internet:  1500
# Entertainment:  4000
# Loan EMI:  3000
# Other Expenses:  5000
# ========== Savings & Insurance ==========
# Emergency Fund Saved:  100000
# Current Investments:  3700

# %%
# ==========================================================
# CELL 5 → FINANCIAL CALCULATIONS
# ==========================================================

total_expenses = (
    rent + groceries + transport +
    school_fees + electricity +
    entertainment + loan_emi +
    other_expenses
)

surplus = monthly_salary - total_expenses

savings_rate = (
    surplus / monthly_salary * 100
    if monthly_salary > 0 else 0
)

target_emergency = total_expenses * 6

# %%
# ==========================================================
# CELL 6 → FINANCIAL ANALYSIS
# ==========================================================

analysis_html = f"""
<div style="
    background:#0D1B2A;
    padding:20px;
    border-radius:15px;
    color:white;
    margin-top:20px;
">

<h2>📈 Financial Analysis</h2>

<table style="width:100%; font-size:18px;">
<tr>
<td><b>Monthly Salary</b></td>
<td>₹{monthly_salary:,.0f}</td>
</tr>

<tr>
<td><b>Total Expenses</b></td>
<td>₹{total_expenses:,.0f}</td>
</tr>

<tr>
<td><b>Total Savings</b></td>
<td>₹{surplus:,.0f}</td>
</tr>

<tr>
<td><b>Savings Rate</b></td>
<td>{savings_rate:.1f}%</td>
</tr>

</table>

</div>
"""

display(HTML(analysis_html))

# %%
# ==========================================================
# CELL 7 → SMART INSIGHTS
# ==========================================================

print("\n========== SMART FINANCIAL INSIGHTS ==========\n")

if entertainment > 5000:
    print("⚠️ Entertainment expenses high hain.")

if groceries > 10000:
    print("⚠️ Grocery spending reduce kar sakte hain.")

if loan_emi > monthly_salary * 0.30:
    print("⚠️ EMI burden high hai.")

if surplus > 0:
    print(f"\n✅ Aap har month approx ₹{surplus:,.0f} save kar sakte hain.")
    print("\nSuggested Focus:")
    print("• SIP Investment")
    print("• PPF / NPS")
    print("• Emergency Fund")

else:
    print("❌ Expenses income se zyada hain.")

# %%
# ==========================================================
# CELL 8 → EXPENSE DISTRIBUTION PIE CHART
# ==========================================================

labels = [
    "Rent",
    "Groceries",
    "Transport",
    "School",
    "Bills",
    "Entertainment",
    "Loan",
    "Other",
    "Savings"
]

values = [
    rent,
    groceries,
    transport,
    school_fees,
    electricity,
    entertainment,
    loan_emi,
    other_expenses,
    max(surplus, 0)
]

chart_df = pd.DataFrame({
    "Category": labels,
    "Amount": values
})

fig = px.pie(
    chart_df,
    names="Category",
    values="Amount",
    hole=0.45,
    title="📉 Expense Distribution"
)

fig.update_traces(
    textposition='inside',
    textinfo='percent+label'
)

fig.update_layout(
    height=700
)

fig.show()

# %%
# ==========================================================
# CELL 9 → RECOMMENDED SAVINGS PLAN
# ==========================================================

if surplus > 0:

    savings_df = pd.DataFrame({

        "Investment Type": [
            "Emergency Fund",
            "Mutual Fund SIP",
            "PPF",
            "Gold Savings",
            "Extra Savings"
        ],

        "Monthly Amount (₹)": [
            int(surplus * 0.30),
            int(surplus * 0.30),
            int(surplus * 0.20),
            int(surplus * 0.10),
            int(surplus * 0.10)
        ]
    })

    print("\n========== RECOMMENDED SAVINGS PLAN ==========\n")

    display(savings_df)

# %%
# ==========================================================
# CELL 10 → GOVERNMENT SAVING SCHEMES
# ==========================================================

schemes_df = pd.DataFrame({

    "Scheme": [
        "PPF",
        "NPS",
        "Atal Pension Yojana",
        "PMJJBY",
        "PMSBY"
    ],

    "Benefits": [
        "Long-term tax free savings",
        "Retirement pension benefits",
        "Guaranteed pension scheme",
        "₹2 lakh life insurance",
        "₹2 lakh accident insurance"
    ]
})

print("\n========== GOVERNMENT SAVING SCHEMES ==========\n")

display(schemes_df)

# %%
# ==========================================================
# CELL 11 → EMERGENCY FUND STATUS
# ==========================================================

progress = min(
    emergency_fund / target_emergency,
    1.0
)

percentage = progress * 100

print("\n========== EMERGENCY FUND STATUS ==========\n")

print(f"Emergency Fund Saved: ₹{emergency_fund:,.0f}")
print(f"Target Emergency Fund: ₹{target_emergency:,.0f}")

print(f"\nCompletion Status: {percentage:.1f}%")

# %%
# ==========================================================
# CELL 12 → FINAL ADVICE
# ==========================================================

print("\n========== FINAL ADVICE ==========\n")

advice = []

if entertainment > 5000:
    advice.append("⚠️ Entertainment expenses reduce kariye.")

if investments == 0:
    advice.append("✅ SIP investment start kariye.")

if emergency_fund < target_emergency:
    advice.append("✅ Emergency fund build kariye.")

if loan_emi > monthly_salary * 0.30:
    advice.append("⚠️ EMI burden kam kariye.")

for item in advice:
    print(item)

print(f"\n🎉 {name}, your sustainable finance report is ready!")
